# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3 # The algorithm starts at x=3
# lr = 0.01 # Learning rate
# lr = 0.05 # Learning rate
# lr = 0.5 # Learning rate
lr = 1 # Learning rate
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function

# %%
'''
需要執行初始值設定, 下列三個
#iteration counter
#Step size  
'''
iter_cnt = 0
iter_his = [iter_cnt]
x_his = [cur_x]
step_size = 1 #just for initialization
'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''
while step_size > precision and iter_cnt<max_iters:
    prev_x = cur_x
    cur_x = cur_x - lr*df(cur_x)
    iter_cnt+=1
    iter_his.append(iter_cnt)
    x_his.append(cur_x)
    step_size = abs(cur_x - prev_x)
    print("the learning rate is",lr, "\nIteration",iter_cnt,"\nX value is",cur_x) #Print iterations
# Out:
# the learning rate is 0.05
# Iteration 1
# X value is 2.2
# the learning rate is 0.05
# Iteration 2
# X value is 1.48
# the learning rate is 0.05
# Iteration 3
# X value is 0.8319999999999999
# the learning rate is 0.05
# Iteration 4
# X value is 0.2487999999999998
# the learning rate is 0.05
# Iteration 5
# X value is -0.2760800000000002
# the learning rate is 0.05
# Iteration 6
# X value is -0.7484720000000002
# the learning rate is 0.05
# Iteration 7
# X value is -1.1736248000000002
# the learning rate is 0.05
# Iteration 8
# X value is -1.5562623200000003
# the learning rate is 0.05
# Iteration 9
# X value is -1.9006360880000004
# the learning rate is 0.05
# Iteration 10
# X value is -2.2105724792000006
# the learning rate is 0.05
# Iteration 11
# X value is -2.4895152312800004
# the learning rate is 0.05
# Iteration 12
# X value is -2.7405637081520005
# the learning rate is 0.05
# Iteration 13
# X value is -2.9665073373368003
# the learning rate is 0.05
# Iteration 14
# ...

# %%
'''
需要執行初始值設定, 下列三個
#iteration counter
#Step size  
'''
iter_cnt = 0
iter_his = [iter_cnt]
x_his = [cur_x]
step_size = 1 #just for initialization
'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''
while step_size > precision and iter_cnt<max_iters:
    prev_x = cur_x
    cur_x = cur_x - lr*df(cur_x)
    iter_cnt+=1
    iter_his.append(iter_cnt)
    x_his.append(cur_x)
    step_size = abs(cur_x - prev_x)
    print("the learning rate is",lr, "\nIteration",iter_cnt,"\nX value is",cur_x) #Print iterations
# Out:
# the learning rate is 0.5
# Iteration 1
# X value is -5.0
# the learning rate is 0.5
# Iteration 2
# X value is -5.0

# %%
'''
需要執行初始值設定, 下列三個
#iteration counter
#Step size  
'''
iter_cnt = 0
iter_his = [iter_cnt]
x_his = [cur_x]
step_size = 1 #just for initialization
'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''
while step_size > precision and iter_cnt<max_iters:
    prev_x = cur_x
    cur_x = cur_x - lr*df(cur_x)
    iter_cnt+=1
    iter_his.append(iter_cnt)
    x_his.append(cur_x)
    step_size = abs(cur_x - prev_x)
    print("the learning rate is",lr, "\nIteration",iter_cnt,"\nX value is",cur_x) #Print iterations
# Out:
# the learning rate is 1
# Iteration 1
# X value is -13
# the learning rate is 1
# Iteration 2
# X value is 3
# the learning rate is 1
# Iteration 3
# X value is -13
# the learning rate is 1
# Iteration 4
# X value is 3
# the learning rate is 1
# Iteration 5
# X value is -13
# the learning rate is 1
# Iteration 6
# X value is 3
# the learning rate is 1
# Iteration 7
# X value is -13
# the learning rate is 1
# Iteration 8
# X value is 3
# the learning rate is 1
# Iteration 9
# X value is -13
# the learning rate is 1
# Iteration 10
# X value is 3
# the learning rate is 1
# Iteration 11
# X value is -13
# the learning rate is 1
# Iteration 12
# X value is 3
# the learning rate is 1
# Iteration 13
# X value is -13
# the learning rate is 1
# Iteration 14
# X value is 3
# the learning rate is 1
# Iteration 15
# X value is -13
# the learning rate is 1
# Iteration 16
# X value is 3
# the learning rate is 1
# Iteration 17
# X value is -13
# the learning rate is 1
# Iteration 18
# X value is 3
# ...
