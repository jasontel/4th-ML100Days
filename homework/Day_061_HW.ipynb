# %% [markdown]
# # 作業
# ### 用 digits (dataset.load_digits()) 資料嘗試跑 t-SNE

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from sklearn import manifold, datasets

# %matplotlib inline
from sklearn import datasets

digits = datasets.load_digits(n_class=6)
X = digits.data
y = digits.target

# %%
n_samples, n_features = X.shape
n_neighbors = 30
tsne = manifold.TSNE(n_components=2, random_state=0, init='pca', learning_rate=200., early_exaggeration=12.)
# Scale and visualize the embedding vectors
def plot_embedding(X, title=None):
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    plt.figure()
    ax = plt.subplot(111)
    for i in range(X.shape[0]):
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=plt.cm.Set1(y[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    if hasattr(offsetbox, 'AnnotationBbox'):
        # only print thumbnails with matplotlib > 1.0
        shown_images = np.array([[1., 1.]])  # just something big
        for i in range(X.shape[0]):
            dist = np.sum((X[i] - shown_images) ** 2, 1)
            if np.min(dist) < 4e-3:
                # don't show points that are too close
                continue
            shown_images = np.r_[shown_images, [X[i]]]
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(digits.images[i], cmap=plt.cm.gray_r),
                X[i])
            ax.add_artist(imagebox)
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)

# t-SNE embedding of the digits dataset
print("Computing t-SNE embedding")

X_tsne = tsne.fit_transform(X)

plot_embedding(X_tsne,
               "t-SNE embedding of the digits")

plt.show()
# Out:
# Computing t-SNE embedding

# %%
pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Using cached https://files.pythonhosted.org/packages/3c/17/41788e4f993ed07ead695c06b350af61adfe528975d071d9758c4a23f96b/tensorflow_gpu-2.2.0-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: google-pasta>=0.1.8 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.16.2)
# Collecting keras-preprocessing>=1.1.0 (from tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl
# Collecting opt-einsum>=2.3.2 (from tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/63/a5/e6c07b08b934831ccb8c98ee335e66b7761c5754ee3cabfe4c11d0b1af28/opt_einsum-3.2.1-py3-none-any.whl
# Requirement already satisfied: gast==0.3.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.3.3)
# Collecting h5py<2.11.0,>=2.10.0 (from tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/a1/6b/7f62017e3f0b32438dd90bdc1ff0b7b1448b6cb04a1ed84f37b6de95cd7b/h5py-2.10.0-cp37-cp37m-win_amd64.whl
# Collecting termcolor>=1.1.0 (from tensorflow-gpu)
# Collecting tensorflow-gpu-estimator<2.3.0,>=2.2.0 (from tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/1c/ea/9b7c9be02b84bdea939d47b9aa3c2f2cfab4153be5817793b623461f6f9c/tensorflow_gpu_estimator-2.2.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.12.0)
# Collecting grpcio>=1.8.6 (from tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/9a/10/7fe727fbdb4086b1afb1bb3c70052fe04c9dffe6cc3db6beb6ad6ce45077/grpcio-1.29.0-cp37-cp37m-win_amd64.whl
# Collecting absl-py>=0.7.0 (from tensorflow-gpu)
# Collecting protobuf>=3.8.0 (from tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/82/6c/c9b57d24685639dfb07b1798bf64e576c3c675a0b9fe0519254d0f9d1e30/protobuf-3.12.2-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: wrapt>=1.11.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.11.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.33.1)
# Collecting astunparse==1.6.3 (from tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl
# Collecting scipy==1.4.1; python_version >= "3" (from tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/61/51/046cbc61c7607e5ecead6ff1a9453fba5e7e47a5ea8d608cc7036586a5ef/scipy-1.4.1-cp37-cp37m-win_amd64.whl
# Collecting tensorboard<2.3.0,>=2.2.0 (from tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/1d/74/0a6fcb206dcc72a6da9a62dd81784bfdbff5fedb099982861dc2219014fb/tensorboard-2.2.2-py3-none-any.whl
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from protobuf>=3.8.0->tensorflow-gpu) (40.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (2.21.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# Collecting google-auth<2,>=1.6.3 (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/88/8c/d161e4653a574e2299bc7d1cae14f08db74f828febaf30a1b7e216680085/google_auth-1.16.0-py2.py3-none-any.whl
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (0.14.1)
# Collecting markdown>=2.6.8 (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/a4/63/eaec2bd025ab48c754b55e8819af0f6a69e2b1e187611dd40cbbe101ee7f/Markdown-3.2.2-py3-none-any.whl
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/51/cd/a0c1f9e4582ea64dddf76c1b808b318d01e3b858a51c715bffab1016ecc7/tensorboard_plugin_wit-1.6.0.post3-py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (2.8)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Collecting cachetools<5.0,>=2.0.0 (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/b3/59/524ffb454d05001e2be74c14745b485681c6ed5f2e625f71d135704c0909/cachetools-4.1.0-py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1 (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl
# Collecting rsa<4.1,>=3.1.4 (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/02/e5/38518af393f7c214357079ce67a317307936896e961e35450b70fad2a9cf/rsa-4.0-py2.py3-none-any.whl
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\programdata\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (0.0.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl
# Collecting pyasn1<0.5.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu)
#   Using cached https://files.pythonhosted.org/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl
# Requirement already satisfied: zipp>=0.3.2 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (0.3.3)
# Installing collected packages: keras-preprocessing, opt-einsum, h5py, termcolor, tensorflow-gpu-estimator, grpcio, absl-py, protobuf, astunparse, scipy, oauthlib, requests-oauthlib, cachetools, pyasn1, pyasn1-modules, rsa, google-auth, google-auth-oauthlib, markdown, tensorboard-plugin-wit, tensorboard, tensorflow-gpu
#   Found existing installation: h5py 2.9.0
#     Uninstalling h5py-2.9.0:
# Note: you may need to restart the kernel to use updated packages.
# tensorboard 2.2.2 has requirement setuptools>=41.0.0, but you'll have setuptools 40.8.0 which is incompatible.
# Could not install packages due to an EnvironmentError: [WinError 5] \u5b58\u53d6\u88ab\u62d2\u3002: 'c:\\programdata\\anaconda3\\lib\\site-packages\\h5py-2.9.0.dist-info\\INSTALLER'
# Consider using the `--user` option or check the permissions.

# %%
pip install --user setuptools --upgrade
# Out:
# Collecting setuptools
#   Using cached https://files.pythonhosted.org/packages/95/95/f657b6e17f00c3f35b5f68b10e46c3a43af353d8856bd57bfcfb1dbb3e92/setuptools-47.1.1-py3-none-any.whl
# Installing collected packages: setuptools
# Successfully installed setuptools-47.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user tensorflow-gpu
# Out:
# Requirement already satisfied: tensorflow-gpu in c:\users\jason\appdata\roaming\python\python37\site-packages (2.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.11.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.33.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.16.2)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorflow-gpu) (1.4.1)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (3.2.1)
# Requirement already satisfied: gast==0.3.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.3.3)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.12.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorflow-gpu) (1.29.0)
# Requirement already satisfied: tensorflow-gpu-estimator<2.3.0,>=2.2.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorflow-gpu) (2.2.0)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorflow-gpu) (2.2.2)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorflow-gpu) (0.9.0)
# Requirement already satisfied: protobuf>=3.8.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorflow-gpu) (3.12.2)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (0.14.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (0.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (1.6.0.post3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (2.21.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (3.2.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (1.16.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (47.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\programdata\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (0.0.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (4.1.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jason\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in c:\users\jason\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jason\appdata\roaming\python\python37\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (3.1.0)
# Requirement already satisfied: zipp>=0.3.2 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (0.3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jason\appdata\roaming\python\python37\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      57
# ---> 58   from tensorflow.python.pywrap_tensorflow_internal import *
#      59
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in <module>
#      27             return _mod
# ---> 28     _pywrap_tensorflow_internal = swig_import_helper()
#      29     del swig_import_helper
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\pywrap_tensorflow_internal.py in swig_import_helper()
#      23             try:
# ---> 24                 _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#      25             finally:
#
# C:\ProgramData\Anaconda3\lib\imp.py in load_module(name, file, filename, details)
#     241         else:
# --> 242             return load_dynamic(name, filename, file)
#     243     elif type_ == PKG_DIRECTORY:
#
# C:\ProgramData\Anaconda3\lib\imp.py in load_dynamic(name, path, file)
#     341             name=name, loader=loader, origin=path)
# --> 342         return _load(spec)
#     343
#
# ImportError: DLL load failed: 找不到指定的模組。
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-d6579f534729> in <module>
# ----> 1 import tensorflow
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\__init__.py in <module>
#      48 import numpy as np
#      49
# ---> 50 from tensorflow.python import pywrap_tensorflow
#      51
#      52 # Protocol buffers
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      67 for some common reasons and solutions.  Include the entire stack trace
#      68 above this error message when asking for help.""" % traceback.format_exc()
# ---> 69   raise ImportError(msg)
#      70
#      71 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\Jason\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\pywrap_tensorflow.py", line 58, in <module>
#     from tensorflow.python.pywrap_tensorflow_internal import *
#   File "C:\Users\Jason\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\pywrap_tensorflow_internal.py", line 28, in <module>
#     _pywrap_tensorflow_internal = swig_import_helper()
#   File "C:\Users\Jason\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\pywrap_tensorflow_internal.py", line 24, in swig_import_helper
#     _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 242, in load_module
#     return load_dynamic(name, filename, file)
#   File "C:\ProgramData\Anaconda3\lib\imp.py", line 342, in load_dynamic
#     return _load(spec)
# ImportError: DLL load failed: 找不到指定的模組。
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.

# %%
pip uninstall tensorflow-gpu
